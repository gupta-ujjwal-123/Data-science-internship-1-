# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread('images/hue_channel.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('Hue_channel')

axs[1][1].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[1][1].set_title('Hue_channel')



plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread('images/ujjwal.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('GUPTA')

axs[1][1].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[1][1].set_title('GUPTA')



plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread('images/output1.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('SVCE')

axs[1][1].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[1][1].set_title('SVCE')
# Out:
# Text(0.5, 1.0, 'SVCE')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread('images/hsv_image.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('DIAMOND')

axs[1][1].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[1][1].set_title('DIAMOND')
# Out:
# Text(0.5, 1.0, 'DIAMOND')
