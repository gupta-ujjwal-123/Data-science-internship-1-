# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np 
print("Packages successfully imported")
# Out:
# Packages successfully imported

# %%
import cv2

input = cv2.imread('images/output1.jpg')

plt.imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))
plt.title('Hello World')

plt.show()

# %%
import cv2

input = cv2.imread('images/ujjwal.jpg')

plt.imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))
plt.title('UJJWAL')

plt.show()

# %%
print (input.shape)
# Out:
# (2304, 1728, 3)

# %%
cv2.imwrite('Reading-Writing-and-displaying/output.jpg', input)
cv2.imwrite('Reading-Writing-and-displaying/output.png', input)
# Out:
# False

# %%
print ('Height of Image:', int(input.shape[0]), 'pixels')
print ('Width of Image: ', int(input.shape[1]), 'pixels')
# Out:
# Height of Image: 2304 pixels
# Width of Image:  1728 pixels

# %%
image = cv2.imread('images/ujjwal.jpg')


gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Original', image)
cv2.imshow('Grayscale', gray_image)

cv2.waitKey()
cv2.destroyAllWindows()
